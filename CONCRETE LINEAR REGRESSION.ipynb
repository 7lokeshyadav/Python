# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
con_df=pd.read_csv("concrete.csv")

# %%
con_df.sample(10)
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 498   333.0    0.0    0.0  192.0           0.0      931.2    842.6   28
# 743   150.9    0.0  183.9  166.6          11.6      991.2    772.2   28
# 477   264.5  111.0   86.5  195.5           5.9      832.6    790.4   28
# 920   181.4    0.0  167.0  169.6           7.6     1055.6    777.8   14
# 45    387.0   20.0   94.0  157.0          11.6      938.0    845.0   56
# 106   155.0    0.0  143.0  193.0           9.0      877.0    868.0   28
# 975   393.0    0.0    0.0  192.0           0.0      940.0    758.0   28
# 906   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 85    273.0    0.0   90.0  199.0          11.0      931.0    762.0   28
# 218   385.0    0.0    0.0  186.0           0.0      966.0    763.0    3
#
#      strength
# 498     31.97
# 743     15.57
# 477     41.54
# 920     21.60
# 45      61.46
# 106      9.74
# 975     39.58
# 906     32.77
# 85      32.24
# 218     14.70

# %%
con_df.isnull().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
con_df.dtypes
# Out:
# cement          float64
# slag            float64
# ash             float64
# water           float64
# superplastic    float64
# coarseagg       float64
# fineagg         float64
# age               int64
# strength        float64
# dtype: object

# %%
sns.pairplot(con_df,diag_kind="con")

# %%
# independent Variable
X=con_df.drop(['strength'],axis=1)

# Dependent Variable
y=con_df[["strength"]]

# %%
# Split X and Y into training and test set in 70:30 ratio
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.30,random_state=1)

# %%
model_1=LinearRegression()
model_1.fit(X_train,y_train)
model_1
# Out:
# LinearRegression()

# %%
model_1.score(X_test,y_test)
# Out:
# 0.6339136715208276

# %%
model_1.score(X_train,y_train)
# Out:
# 0.603148754063023
